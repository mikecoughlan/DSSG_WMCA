# %%
#importing all the required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from io import BytesIO

# %%
#Reading the CSV
df=pd.read_csv("data_cleaning.csv")

# %%
#Making the CSV file of Latitude and Longitude
new_df = df[['LATITUDE','LONGITUDE']]
new_df.to_csv("yo.csv")

# %%
#The Latitude Values
new_df.LATITUDE
# Out:
# 0         52.484686
# 1         52.606000
# 2         52.606045
# 3         52.616470
# 4         52.616362
#             ...
# 106585    52.492321
# 106586    52.481112
# 106587    52.492280
# 106588    52.549617
# 106589          NaN
# Name: LATITUDE, Length: 106590, dtype: float64

# %%
#The Longitude Values
new_df.LONGITUDE
# Out:
# 0        -1.797840
# 1        -2.119558
# 2        -2.119676
# 3        -1.997316
# 4        -1.997325
#             ...
# 106585   -2.003750
# 106586   -1.829059
# 106587   -2.148764
# 106588   -1.894580
# 106589         NaN
# Name: LONGITUDE, Length: 106590, dtype: float64

# %%
import requests as rq

for i in range(0,100):
  
  url = 'https://maps.googleapis.com/maps/api/streetview?' #the google streetview url
  size = '400x400' #size needed
  lat = new_df.LATITUDE[i]
  longi = new_df.LONGITUDE[i]
  y=str(lat)
  z=str(longi)
  api_key = 'AIzaSyCTDlH3C2gR8YCYa6IOGdqViVfhr2S9_AE' #api key

  final_url = url+ 'size=' + size + '&location=' + y + ',' + z + '&fov=80&heading=70&pitch=0&key=' + api_key #final url

  
  img = rq.get(final_url, stream = True)
    
  image=Image.open(BytesIO(img.content)) #opening the image content
        
  display(image)
    

  i+=1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAEDA7390>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDB2722150>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAE61BCD0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAEDA7510>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDADE2FCD0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAEDA7310>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDADCECBD0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAE9DC390>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAF589E50>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FBDAE39CB10>
