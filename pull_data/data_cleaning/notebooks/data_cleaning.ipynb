# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/210622_merge.csv")

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://epc.opendatacommunities.org/docs/guidance#technical_notes"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.find_all("div", class_="field")
# Out:
# [<div class="field">
#  <dt class="fieldlabel" id="field_domestic_LMK_KEY">
#  							LMK key
#  							<span class="dbid">LMK_KEY</span>
#  <span class="dbid">
#  										varchar
#  											64
#  									</span>
#  </dt>
#  <dd>Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.</dd>
#  </div>,
#  <div class="field">
#  <dt class="fieldlabel" id="field_domestic_ADDRESS1">
#  							Address 1
#  							<span class="dbid">ADDRESS1</span>
#  <span class="dbid">
#  										varchar
#  											84
#  									</span>
#  </dt>
#  <dd>First line of the address</dd>
#  </div>,
#  <div class="field">
#  <dt class="fieldlabel" id="field_domestic_ADDRESS2">
#  							Address 2
#  							<span class="dbid">ADDRESS2</span>
#  <span class="dbid">
#  										varchar
#  											100
#  									</span>
#  </dt>
#  <dd>Second line of the address</dd>
#  </div>,
#  <div class="field">
# ...

# %%
var_name, var_desc = [], []

for div in soup.find_all("div", class_="field"):
    name = div.find(class_="dbid")
    if name:
        var_name.append(name.text)
        var_desc.append(div.find("dd").text)

# %%
import pandas as pd
df = pd.DataFrame({
    "variable": var_name,
    "description": var_desc
})

# %%
df.to_csv("../data/raw/data_dic_EPC.csv", index=False)
