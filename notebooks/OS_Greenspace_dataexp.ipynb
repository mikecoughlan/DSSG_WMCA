# %%
import geopandas as gpd

# %%
import pandas as pd
from pandas_profiling import ProfileReport

filename = '/Users/meghna_mac2/PycharmProjects/WMCA/OS Open Greenspace (GPKG) GB/data/opgrsp_gb.gpkg'
greenspace = gpd.read_file(filename)

# %%
greenspace
# Out:
#                                             id                    accessType  \
# 0       idFF5F4A6A-8B32-47CD-8FB5-4D007A6CCF11                    Pedestrian
# 1       idF40C0F0C-20A1-4C87-9FFB-E32C08E53F4A                    Pedestrian
# 2       idCB2C76E9-C65D-4CF7-BD97-5C486C029482  Motor Vehicle And Pedestrian
# 3       id260B2895-6B95-4EA3-9518-5338B6D56E63                    Pedestrian
# 4       idE445C772-9D25-4B73-9B08-CCBAD290B775  Motor Vehicle And Pedestrian
# ...                                        ...                           ...
# 295406  id0D718FBE-EAB3-40A4-82B6-7A5457678496                    Pedestrian
# 295407  idF5DA0BD4-F795-482C-981F-87E7178DB336                    Pedestrian
# 295408  id1B0B0D7C-5C75-4849-B38E-BF8E58971123                    Pedestrian
# 295409  id83CFF34A-1B76-4990-B1E8-301357988F41                    Pedestrian
# 295410  id75E9D9F2-7588-4521-A713-0718881CB582                    Pedestrian
#
# ...
