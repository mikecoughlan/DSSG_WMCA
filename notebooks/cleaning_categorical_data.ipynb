# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/WMCA/data_cleaning.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (57) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Standardising entries

# %% [markdown]
# We will correct recurrent errors in the descriptions and translate/remove the Welsh in the entries.

# %%
cat_var = df.select_dtypes(include= ['object','category']).columns.tolist()

# Not these variables
cat_var.remove('lmk-key')
cat_var.remove('address')
cat_var.remove('postcode')

# %%
# remove bilingual 
for c in cat_var:
  df[c] = df[c].str.replace(r"\|(.*)", "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for c in ['floor-description','walls-description','roof-description']:
    # standardising the unit used
    df[c] = df[c].str.replace(r"W(.*?)K",'W/m²K')
    # removing nonsense 
    df[c] = df[c].str.replace("\*\*\* INVALID INPUT Code \: 57 \*\*\*","")
    # cleaning up 
    df[c] = df[c].str.replace(r'\.$','')
    df[c] = df[c].str.replace(r'\,$','')
    df[c] = df[c].str.replace("  \+"," +")
    df[c] = df[c].str.replace("[ \t]+$","")
    df[c] = df[c].str.replace('  ',' ')
    df[c] = df[c].str.replace('Average thermal transmittance 1 ','Average thermal transmittance 1.00 ')
    df[c] = df[c].str.replace('Average thermal transmittance =','Average thermal transmittance')
    df[c] = df[c].str.rstrip(' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# removing phrases like as built which aren't adding anything
df['walls-description'] = df['walls-description'].str.replace("\(assumed\)","")
df['walls-description'] = df['walls-description'].str.replace("as built, ","")
df['walls-description'] = df['walls-description'].str.replace("cavity\.","cavity wall,")
# standardising punctuation
df['walls-description'] = df['walls-description'].str.replace("solid brick\.","solid brick,")
# standardising language
df['walls-description'] = df['walls-description'].replace(
    regex=["granite or whin,", "stone \(granite or whin\)\."],
    value="granite or whinstone,")
df['walls-description'] = df['walls-description'].replace(
    regex=["with external insulation", "with internal insulation", 
     "with additional insulation", "with insulation"],
     value="insulated")
# clean up
df['walls-description'] = df['walls-description'].str.replace('\+ chr\(13\) \+','+')
df['walls-description'] = df['walls-description'].str.replace("[ \t]+$","")
df['walls-description'] = df['walls-description'].str.replace('timber frame\.','timber frame,')
df['walls-description'] = df['walls-description'].str.replace('\?','')
df['walls-description'] = df['walls-description'].str.replace('system built\.','system built,')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
# standardising units
df['roof-description'] = df['roof-description'].str.replace(" mm",'mm')
df['roof-description'] = df['roof-description'].str.replace(">= 300mm",">=300mm")
df['roof-description'] = df['roof-description'].str.replace(">=300mm","300+mm")
# standardising descriptions
df['roof-description'] = df['roof-description'].str.replace("Roof room,","Roof room(s),")
df['roof-description'] = df['roof-description'].str.replace("another dwelling above","other premises above")
df['roof-description'] = df['roof-description'].replace(
    regex=["Other premises above","Dwelling Above"],
    value="(other premises above)")
df['roof-description'] = df['roof-description'].str.replace(r"0 W/m²K",r" W/m²K")
df['roof-description'] = df['roof-description'].str.replace("  W/m²K"," 0.0 W/m²K")
df['roof-description'] = df['roof-description'].str.replace("Roof room\(s\), no insulation\(assumed\)","Roof room(s), no insulation (assumed)")
df['roof-description'] = df['roof-description'].str.replace("\(assumed\)","")
# cleanup
df['roof-description'] = df['roof-description'].str.replace("mmmm","mm")
df['roof-description'] = df['roof-description'].str.replace(",mm",",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
# removing assumed
df['floor-description'] = df['floor-description'].str.replace("\(assumed\)","")
# standardising language
df['floor-description'] = df['floor-description'].replace(
    regex=["\(another dwelling below\)", "\(other premises below\)"],
    value='other premises below') 
df['floor-description'] = df['floor-description'].str.replace("solid.",'solid,') 
df['floor-description'] = df['floor-description'].str.replace("uninsulated",'no insulation,') 
df['floor-description'] = df['floor-description'].str.replace("insulation=100mm",'100 mm insulation') 
df['floor-description'] = df['floor-description'].str.replace(", \(assumed\)",' (assumed)')
df['floor-description'] = df['floor-description'].str.replace("insulation=25mm",'25 mm insulation')
df['floor-description'] = df['floor-description'].str.replace("insulation=75mm",'75 mm insulation')
df['floor-description'] = df['floor-description'].str.replace("limited insulated",'limited insulation')
# cleanup
df['floor-description'] = df['floor-description'].str.replace(r'^, ','')
df['floor-description'] = df['floor-description'].str.replace(r'\?','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   app.launch_new_instance()

# %%
# Extract thermal transmittance feature
for c in ['floor-description','walls-description','roof-description']:
  col_name = c.split('-')[0] + "-thermal-transmittance"
  transmittance_col = df[c].str.findall(r'(\d.\d*) W/m²K')
  df[col_name] = round(transmittance_col.str[0].astype(float),2)

# %%
df['construction-age-band'] = df['construction-age-band'].str.replace("England and Wales: ", "")

# %%
df['transaction-type'] = df['transaction-type'].str.replace(" - this is for backwards compatibility only and should not be used","")
df['transaction-type'] = df['transaction-type'].str.replace("Stock Condition Survey", "Stock condition survey")
df['transaction-type'] = df['transaction-type'].replace("not recorded", np.nan)

# %%
df['main-fuel'] = df['main-fuel'].str.replace(" - this is for backwards compatibility only and should not be used","")

# %%
df['tenure'] = df['tenure'].str.replace('Rented', 'rental')
df['tenure'] = df['tenure'].replace('Not defined - use in the case of a new dwelling for which the intended tenure in not known. It is no', np.nan)
df['tenure'] = df['tenure'].str.lower()

# %%
df['floor-level'] = df['floor-level'].replace(
    regex=['ground floor', '00', '0'], 
    value='Ground')
df['floor-level'] = df['floor-level'].str.lstrip('0')
df['floor-level'] = df['floor-level'].replace(
    regex=[r'\dth', r'\dnd', r'\drd'], 
    value='')
df['floor-level'] = df['floor-level'].replace('Basement', '-1')

# %%
df['glazed-area'] = df['glazed-area'].replace('Not Defined', np.nan)

# %%
# standardising language
df['mainheatcont-description'] = df['mainheatcont-description'].str.lower()
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("programmer, no thermostat","programmer, no room thermostat")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("flat rate charging\*","flat rate charging")
df['mainheatcont-description'] = df['mainheatcont-description'].replace(
    regex=[r"\+",r"\&"] ,
    value="and")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("trv.s","trvs")
df['mainheatcont-description'] = df['mainheatcont-description'].replace(
    regex=["thermostats", " stat", "thermostatic"],
    value="thermostat")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("communit ","community ")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("to the use of community heating","to use of community heating")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("controls","control")
df['mainheatcont-description'] = df['mainheatcont-description'].replace(
    regex=["prog ","program "],
    value="programmer ")
df['mainheatcont-description'] = df['mainheatcont-description'].replace(
    regex=["programmerand",r"programmer\?and"],
    value="programmer and")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("delayed start thermostat and program and trvs","delayed start thermostat, program and trvs")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("flat rate charging, programmer no room thermostat","flat rate charging, programmer, no room thermostat")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace(" 2 "," two ")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("roomstat","room thermostat")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("programmer and room thermostat and trvs","programmer, room thermostat and trvs")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("programmer and trvs and boiler energy manager","programmer, trvs and boiler energy manager")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("programmer and trvs and bypass","programmer, trvs and bypass")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("programmer and trvs and flow switch","programmer, trvs and flow switch")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("temp+$","temperature")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("no thermostat control of room temperature","no thermostat control")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("appliance thermostat and programmer","programmer and appliance thermostat")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("delayed start thermostat and programmer and trvs","delayed start thermostat, programmer and trvs")
df['mainheatcont-description'] = df['mainheatcont-description'].str.replace("no time or thermostat control of temperature","no time or thermostat control of room temperature")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
df['hotwater-description'] = df['hotwater-description'].str.replace(r"\|.*", '')
df['hotwater-description'] = df['hotwater-description'].str.replace("cylinder thermostat","cylinderstat")
df['hotwater-description'] = df['hotwater-description'].replace(
    regex=["No system present :", "No hot water system present -"],
    value="No system present:")
df['hotwater-description'] = df['hotwater-description'].replace(
    regex=["From community scheme", "community scheme"],
    value="Community scheme")
df['hotwater-description'] = df['hotwater-description'].str.replace("Community heat pump","Community scheme with CHP")
df['hotwater-description'] = df['hotwater-description'].replace(
    regex=["From secondary heater","From second main heating system"],
    value="From secondary system")
df['hotwater-description'] = df['hotwater-description'].str.replace("SAP05:Hot-Water","SAP:Hot-Water")
df['hotwater-description'] = df['hotwater-description'].str.replace("plus solar, no cylinderstat","no cylinderstat, plus solar")
df['hotwater-description'] = df['hotwater-description'].str.replace("none","No system present: electric immersion assumed")
df['hotwater-description'] = df['hotwater-description'].str.replace("plus solar, flue gas heat recovery","flue gas heat recovery, plus solar")
df['hotwater-description'] = df['hotwater-description'].str.replace("no cylinderstat, no cylinderstat","no cylinderstat")
df['hotwater-description'] = df['hotwater-description'].replace("***SAMPLE***",np.nan)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df['windows-description'] = df['windows-description'].str.lower()
df['windows-description'] = df['windows-description'].str.replace("glazed","glazing")
df['windows-description'] = df['windows-description'].str.replace("fully","full")
df['windows-description'] = df['windows-description'].str.replace("single glazingsingle glazing","single glazing")
df['windows-description'] = df['windows-description'].str.replace("single glazingdouble glazing","single glazing and double glazing")
df['windows-description'] = df['windows-description'].str.replace("single glazingsecondary glazing","single glazing and secondary glazing")
df['windows-description'] = df['windows-description'].str.replace("  "," ")

# %%
df['secondheat-description1'] = df.apply(lambda row: row['lighting-description'] if 'lighting' in str(row['secondheat-description']) else row['secondheat-description'],axis = 1)
df['lighting-description1'] = df.apply(lambda row: row['secondheat-description'] if 'lighting' in str(row['secondheat-description']) else row['lighting-description'],axis = 1)
df.drop(columns= ['secondheat-description','lighting-description'],axis=1,inplace=True)
df.rename(columns={'secondheat-description1':'secondheat-description','lighting-description1':'lighting-description'},inplace=True)

# %%
## CONVERT TO NUMERICAL ##
df['lighting-description'] = df['lighting-description'].str.lower()
# combining ways of saying all lights are low energy
df['lighting-description'] = df['lighting-description'].str.replace(r'low energy lighting in 120% of fixed outlets','low energy lighting in all fixed outlets')
df['lighting-description'] = df['lighting-description'].str.replace(r'low energy lighting 100% of fixed outlets','low energy lighting in all fixed outlets')

# %%
df['secondheat-description'] = df['secondheat-description'].str.rstrip(', ')
df['secondheat-description'] = df['secondheat-description'].str.replace('LNG', 'LPG')
df['secondheat-description'] = df['secondheat-description'].str.replace('lpg', 'LPG')
df['secondheat-description'].replace(regex=[r'\,\s\(null\)', r'\s*\(assumed\)'], value='', inplace=True)

# %%
df['main-heating-controls'] = df['main-heating-controls'].replace('%%MAINHEATCONTROL%%', np.nan)
df['main-heating-controls'] = df['main-heating-controls'].astype(float)

# %%
## main-heat-description ##

# %%
for c in cat_var:
  print(f'\nVariable: {c}')
  print(df[c].unique())
# Out:
# Variable: uprn-source
# ['Address Matched' 'Energy Assessor']
#
# Variable: construction-age-band
# ['1950-1966' nan 'before 1900' '2007 onwards' '1900-1929' '1983-1990'
#  '1967-1975' '1930-1949' '1996-2002' '1976-1982' '1991-1995' '2003-2006'
#  '2007-2011' '2012 onwards' '2020' '2021' '2022' '2019' '2016' '2015'
#  '2017' '2018' '1950' '2014' '2010' '2004' '2011' '2012' '2013' '1935']
#
# Variable: potential-energy-rating
# ['C' 'B' 'E' 'D' 'F' 'G' 'A']
#
# Variable: mainheat-energy-eff
# ['Very Good' 'Poor' 'Average' 'Good' nan 'Very Poor']
#
# Variable: windows-env-eff
# ['Average' 'Good' 'Poor' 'Very Good' 'Very Poor' nan]
#
# Variable: lighting-energy-eff
# ['Very Good' 'Average' 'Very Poor' 'Poor' 'Good' nan]
#
# Variable: glazed-type
# ['double glazing installed before 2002' nan
#  'double glazing installed during or after 2002' 'secondary glazing'
#  'single glazing' 'double glazing, unknown install date' 'triple glazing'
#  'double, known data' 'triple, known data']
#
# Variable: address3
# [nan 'Darlaston' '785 Stratford Road' ... '42 Belper Row'
#  '1 Woodfall Avenue' '357 Flaxley Road']
#
# Variable: mainheatcont-description
# ['programmer, room thermostat and trvs'
#  'time and temperature zone control' 'automatic charge control'
#  'programmer and room thermostat' 'programmer, no room thermostat'
#  'programmer and appliance thermostat' 'programmer, trvs and bypass'
#  'programmer, trvs and boiler energy manager' 'celect control'
#  'flat rate charging, programmer and trvs' 'manual charge control'
#  'no time or thermostat control of room temperature'
#  'sap05:main-heating-control' 'flat rate charging, room thermostat only'
#  'appliance thermostat' 'temperature zone control'
#  'flat rate charging, nothermostat control of room temperature'
#  'flat rate charging, no thermostat control' 'none' 'room thermostat only'
#  'no thermostat control' 'programmer and at least two room thermostat'
#  'flat rate charging, programmer and roomthermostat'
#  'flat rate charging, programmer and room thermostat'
#  'flat rate charging, programmer, no room thermostat'
#  'charging system linked to use of community heating, programmer and trvs'
#  'unit charging, programmer and trvs' 'celect-type control'
#  'programmer, trvs and flow switch' 'rhaglennydd a thermostat ystafell'
#  'thermostat ystafell yn unig'
#  'delayed start thermostat, programmer and trvs'
#  'flat rate charging, trvs' 'trvs and bypass'
#  'charging system linked to use of community heating, programmer and room thermostat'
#  'charging system linked to use of community heating, trvs'
#  'charging system linked to use of community heating, room thermostat only'
#  'rhaglennydd, trvs a falf osgoi' 'not relevant (supplies dhw only)'
#  'dim rheolaeth amser na rheolaeth thermostatig ar dymheredd yr ystafell'
#  'charging system linked to use of community heating, programmer and at least two room thermostat'
#  'control for high heat retention storage heaters'
#  'rhaglennydd, thermostat ystafell a trvs'
#  'flat rate charging, programmer and at least two room thermostat'
#  'rhaglennydd, dim thermostat ystafell'
#  'charging system linked to use of community heating, programmer and at least two roomthermostats'
#  '2207 time and temperature zone control']
#
# Variable: property-type
# ['House' 'Flat' 'Bungalow' 'Maisonette' 'Park home']
#
# Variable: energy-tariff
# ['Single' 'standard tariff' nan 'off-peak 10 hour' 'dual'
#  'off-peak 7 hour' '24 hour' 'dual (24 hour)' 'off-peak 18 hour' '5']
#
# Variable: mechanical-ventilation
# ['natural' nan 'mechanical, supply and extract' 'mechanical, extract only']
#
# Variable: solar-water-heating-flag
# ['N' nan 'Y']
#
# Variable: constituency
# ['E14000568' 'E14001049' 'E14001011' 'E14000931' 'E14001012' 'E14000722'
#  'E14000650' 'E14000649' 'E14000672' 'E14001029' 'E14000531' 'E14001016'
#  'E14000560' 'E14000564' 'E14000567' 'E14000651' 'E14000563' 'E14000985'
#  'E14000562' 'E14001030' 'E14001050' 'E14000561' 'E14000812' 'E14000566'
#  'E14000976' 'E14000565' 'E14001051' 'E14000671' 'E14000767' 'E14000945'
#  'E14000759' 'E14000986' 'E14000605' 'E14000905' 'E14000803' 'E14000854'
#  'E14000791' 'E14000618' 'E14000977' 'E14000599']
#
# Variable: floor-description
# ['Suspended, no insulation ' 'Average thermal transmittance 0.17 W/m²K'
#  'Average thermal transmittance 0.18 W/m²K'
#  'Average thermal transmittance 0.20 W/m²K' 'Solid, no insulation '
#  'Average thermal transmittance 0.19 W/m²K' 'other premises below'
#  'Average thermal transmittance 0.25 W/m²K'
#  'To external air, no insulation, ' 'Other premises below'
#  'Average thermal transmittance 0.16 W/m²K'
#  'Average thermal transmittance 0.22 W/m²K'
#  'Average thermal transmittance 0.21 W/m²K' 'Solid, insulated '
#  'SAP05:Floor' 'Solid, limited insulation '
#  'Average thermal transmittance 0.48 W/m²K' 'Suspended, insulated '
#  'To unheated space, no insulation, '
#  'Average thermal transmittance 0.01 W/m²K' 'To external air, insulated '
#  'To unheated space, insulated' 'To unheated space, limited insulation '
#  'To external air, insulated' 'Suspended, limited insulation '
#  'To unheated space, insulated '
#  'Average thermal transmittance 0.36 W/m²K'
#  'To external air, limited insulation '
#  'To unheated space, no insulation ' 'Suspended, insulated'
#  'Average thermal transmittance 0.15 W/m²K'
#  'Average thermal transmittance 0.37 W/m²K' 'Solid, insulated'
#  'Average thermal transmittance 0.23 W/m²K'
#  'Average thermal transmittance 0.27 W/m²K'
#  'Average thermal transmittance 0.28 W/m²K'
#  'To external air, no insulation '
#  'Average thermal transmittance 0.24 W/m²K'
#  'Average thermal transmittance 1.20 W/m²K'
#  'Average thermal transmittance 0.26 W/m²K'
#  'Average thermal transmittance 0.29 W/m²K'
#  'Average thermal transmittance 0.80 W/m²K'
#  'Average thermal transmittance 0.33 W/m²K'
#  'Average thermal transmittance 0.38 W/m²K'
#  'Average thermal transmittance 0.39 W/m²K'
#  'Average thermal transmittance 0.31 W/m²K'
#  'Average thermal transmittance 0.55 W/m²K'
#  'Average thermal transmittance 0.35 W/m²K'
#  'Average thermal transmittance 0.32 W/m²K'
#  'Average thermal transmittance 0.42 W/m²K'
#  'Average thermal transmittance 0.14 W/m²K'
#  'Average thermal transmittance 0.56 W/m²K'
#  'Average thermal transmittance 0.13 W/m²K'
#  'Solet, wedii inswleiddio (rhagdybiaeth)'
#  'Average thermal transmittance 0.34 W/m²K'
#  'Average thermal transmittance 0.43 W/m²K'
#  'Average thermal transmittance 0.30 W/m²K'
#  'Average thermal transmittance 0.75 W/m²K'
#  'Average thermal transmittance 0.41 W/m²K'
#  'Average thermal transmittance 0.12 W/m²K'
#  'Average thermal transmittance 0.63 W/m²K'
#  'Average thermal transmittance 0.62 W/m²K'
#  'Average thermal transmittance 0.11 W/m²K' 'no insulation ' 'insulated '
#  'Average thermal transmittance 0.82 W/m²K'
#  'Average thermal transmittance 2.05 W/m²K'
#  'Average thermal transmittance 0.57 W/m²K'
#  'Average thermal transmittance 0.08 W/m²K'
#  'Average thermal transmittance 0.40 W/m²K'
#  'Average thermal transmittance 0.02 W/m²K'
#  'Average thermal transmittance 0.52 W/m²K'
#  'Average thermal transmittance 0.44 W/m²K'
#  'Average thermal transmittance 0.45 W/m²K'
#  'Average thermal transmittance 0.10 W/m²K' 'limited insulation '
#  'Average thermal transmittance 0.50 W/m²K'
#  'Average thermal transmittance 0.00 W/m²K'
#  'Average thermal transmittance 1.47 W/m²K'
#  'Average thermal transmittance 0.93 W/m²K'
#  'Average thermal transmittance 0.76 W/m²K'
#  'Average thermal transmittance 0.47 W/m²K'
#  '(Same dwelling below) insulated '
#  'Average thermal transmittance 0.03 W/m²K'
#  'Average thermal transmittance 0.66 W/m²K'
#  'Average thermal transmittance 0.70 W/m²K' nan
#  'Average thermal transmittance 0.60 W/m²K'
#  'Average thermal transmittance 0.95 W/m²K'
#  'Average thermal transmittance 1.02 W/m²K'
#  'Average thermal transmittance 0.09 W/m²K'
#  'Crog, dim inswleiddio (rhagdybiaeth)'
#  'Solet, dim inswleiddio (rhagdybiaeth)'
#  'Average thermal transmittance 0.69 W/m²K'
#  'Average thermal transmittance 0.72 W/m²K'
#  'Average thermal transmittance 0.78 W/m²K'
#  'Average thermal transmittance 0.51 W/m²K'
#  'Average thermal transmittance 0.74 W/m²K'
#  'Average thermal transmittance 0.46 W/m²K'
#  'Average thermal transmittance 0 W/m²K'
#  'Average thermal transmittance 0.54 W/m²K'
#  'Average thermal transmittance 0.68 W/m²K'
#  'Average thermal transmittance 0.58 W/m²K'
#  'Average thermal transmittance 0.53 W/m²K'
#  'Average thermal transmittance 0.67 W/m²K'
#  'Average thermal transmittance 0.79 W/m²K'
#  'Average thermal transmittance 0.65 W/m²K'
#  'Average thermal transmittance 0.59 W/m²K' 'Conservatory'
#  '(anheddiad arall islaw)' 'Average thermal transmittance 0.06 W/m²K'
#  'Average thermal transmittance 0.77 W/m²K'
#  'Average thermal transmittance 0.61 W/m²K'
#  'Average thermal transmittance 0.73 W/m²K'
#  'Average thermal transmittance 3.37 W/m²K'
#  'Average thermal transmittance 0.90 W/m²K'
#  'Average thermal transmittance 0.07 W/m²K'
#  'Average thermal transmittance 0.87 W/m²K'
#  'Average thermal transmittance 0.71 W/m²K'
#  'Average thermal transmittance 0.2 W/m²K'
#  'Average thermal transmittance 1.06 W/m²K'
#  'Average thermal transmittance 1.04 W/m²K'
#  'Average thermal transmittance 1.00 W/m²K'
#  'Average thermal transmittance 0.04 W/m²K'
#  'Average thermal transmittance 0.05 W/m²K'
#  'Average thermal transmittance 0.49 W/m²K'
#  'Average thermal transmittance 0.64 W/m²K'
#  'Average thermal transmittance 1.50 W/m²K'
#  'Average thermal transmittance 0.97 W/m²K'
#  'Average thermal transmittance 1.05 W/m²K'
#  'Average thermal transmittance 0.83 W/m²K'
#  'Average thermal transmittance 1.13 W/m²K'
#  'Average thermal transmittance 0.92 W/m²K'
#  'Average thermal transmittance 3.23 W/m²K'
#  'Average thermal transmittance 2.49 W/m²K'
#  'Average thermal transmittance 0.91 W/m²K'
#  'Average thermal transmittance 1.28 W/m²K'
#  'Average thermal transmittance 0.81 W/m²K'
#  'Average thermal transmittance 1.55 W/m²K'
#  'Average thermal transmittance 0.94 W/m²K'
#  'Average thermal transmittance 0.99 W/m²K'
#  'Average thermal transmittance 0.89 W/m²K'
#  'Average thermal transmittance 0.86 W/m²K'
#  'Average thermal transmittance 1.29 W/m²K'
#  'Average thermal transmittance 1.70 W/m²K'
#  'Average thermal transmittance 1.68 W/m²K'
#  'Average thermal transmittance 3.05 W/m²K'
#  'Average thermal transmittance 1.33 W/m²K'
#  'Average thermal transmittance 1.22 W/m²K'
#  'Average thermal transmittance 1.95 W/m²K'
#  'Average thermal transmittance 2.39 W/m²K'
#  'Average thermal transmittance 1.83 W/m²K'
#  'Average thermal transmittance 1.25 W/m²K']
#
# Variable: local-authority
# ['E08000025' 'E08000031' 'E08000030' 'E08000029' 'E08000027' 'E08000026'
#  'E08000028' 'E07000222' 'E07000196' 'E09000026' 'E07000194' 'E07000234'
#  'E07000220' 'E06000040' 'E07000218' 'E07000192' 'E07000219' 'E07000221'
#  'E06000023']
#
# Variable: built-form
# ['Mid-Terrace' 'Detached' 'End-Terrace' nan 'Semi-Detached'
#  'Enclosed End-Terrace' 'Enclosed Mid-Terrace']
#
# Variable: windows-description
# ['full double glazing' 'partial double glazing' 'high performance glazing'
#  'partial secondary glazing' 'single glazing' 'sap05:windows'
#  'full secondary glazing' 'full triple glazing'
#  'multiple glazing throughout' 'partial triple glazing'
#  'single and multiple glazing' 'secondary glazing' 'mostly double glazing'
#  'gwydrau eilaidd llawn' 'gwydrau dwbl llawn' 'some double glazing'
#  'mostly secondary glazing' nan 'some secondary glazing'
#  'mostly multiple glazing' 'partial multiple glazing'
#  'single glazing and double glazing' 'some multiple glazing'
#  'single glazing and secondary glazing' 'double glazing'
#  'multiple glazing throughout double glazing' 'mostly triple glazing'
#  'some triple glazing' 'multiple glazing throughout ' 'gwydrau sengl'
#  'gwydrau dwbl gan mwyaf']
#
# Variable: glazed-area
# ['Normal' nan 'More Than Typical' 'Much More Than Typical'
#  'Less Than Typical' 'Much Less Than Typical']
#
# Variable: inspection-date
# ['2003-11-24 00:00:00' '2006-06-30 00:00:00' '2006-08-07 00:00:00' ...
#  '2022-03-29 00:00:00' '2022-03-30 00:00:00' '2022-03-31 00:00:00']
#
# Variable: mains-gas-flag
# ['Y' nan 'N']
#
# Variable: address1
# ['120, Stud Lane' '1' '10 Humphreys Road' ... '1 West Willows'
#  '12 Oakhurst Road' '4 Springfield Avenue']
#
# Variable: constituency-label
# ['Birmingham, Yardley' 'Wolverhampton North East' 'Walsall North'
#  'Solihull' 'Walsall South' 'Halesowen and Rowley Regis'
#  'Coventry North West' 'Coventry North East' 'Dudley South'
#  'West Bromwich East' 'Aldridge-Brownhills' 'Warley'
#  'Birmingham, Edgbaston' 'Birmingham, Ladywood' 'Birmingham, Selly Oak'
#  'Coventry South' 'Birmingham, Hodge Hill' 'Sutton Coldfield'
#  'Birmingham, Hall Green' 'West Bromwich West' 'Wolverhampton South East'
#  'Birmingham, Erdington' 'Meriden' 'Birmingham, Perry Barr' 'Stourbridge'
#  'Birmingham, Northfield' 'Wolverhampton South West' 'Dudley North'
#  'Kenilworth and Southam' 'South Staffordshire' 'Ilford North' 'Tamworth'
#  'Bromsgrove' 'Rugby' 'Maidenhead' 'North Warwickshire' 'Lichfield'
#  'Cannock Chase' 'Stratford-on-Avon' 'Bristol East']
#
# Variable: roof-energy-eff
# ['Poor' 'Very Good' 'Average' nan 'Good' 'Very Poor']
#
# Variable: roof-description
# ['Pitched, 50mm loft insulation'
#  'Average thermal transmittance 0.14 W/m²K'
#  'Pitched, 75mm loft insulation' '(other premises above)'
#  'Average thermal transmittance 0.13 W/m²K'
#  'Average thermal transmittance 0.17 W/m²K'
#  'Average thermal transmittance 0.2 W/m²K'
#  'Average thermal transmittance 0.16 W/m²K'
#  'Average thermal transmittance 0.12 W/m²K'
#  'Pitched, 200mm loft insulation' 'Pitched, 100mm loft insulation'
#  'Average thermal transmittance 0.21 W/m²K'
#  'Average thermal transmittance 0.19 W/m²K' 'Flat, insulated '
#  'Pitched, 250mm loft insulation'
#  'Average thermal transmittance 0.18 W/m²K' 'Roof room(s), no insulation '
#  'Pitched, 150mm loft insulation' 'Pitched, insulated '
#  'Pitched, limited insulation ' 'SAP05:Roof'
#  'Pitched, 12mm loft insulation'
#  'Average thermal transmittance 0.09 W/m²K' 'Flat, limited insulation '
#  'Roof room(s), insulated' 'Roof room(s), insulated '
#  'Pitched, 300+mm loft insulation' 'Pitched, insulated at rafters'
#  'Pitched, no insulation' 'Pitched, 25mm loft insulation'
#  'Average thermal transmittance 0.24 W/m²K' 'Pitched, no insulation '
#  'Average thermal transmittance 0.15 W/m²K'
#  'Pitched, 300mm loft insulation' 'Flat, no insulation ' 'Flat'
#  'Roof room(s), ceiling insulated' 'Roof room(s), limited insulation '
#  'Pitched, 0mm loft insulation' 'Roof room(s), no insulation'
#  'Flat, insulated' 'Pitched' 'Thatched' 'Pitched, 270mm loft insulation'
#  'Flat, limited insulation' 'Pitched, Unknown loft insulation'
#  'Roof room(s), thatched' 'Average thermal transmittance 0.05 W/m²K'
#  'Average thermal transmittance 0.1 W/m²K'
#  'Average thermal transmittance 0.31 W/m²K'
#  'Average thermal transmittance 0.25 W/m²K'
#  'Average thermal transmittance 0.0 W/m²K'
#  'Average thermal transmittance 0.02 W/m²K'
#  'Average thermal transmittance 0.04 W/m²K'
#  'Average thermal transmittance 0.08 W/m²K'
#  'Average thermal transmittance 0.22 W/m²K'
#  'Average thermal transmittance 0.6 W/m²K'
#  'Average thermal transmittance 0.26 W/m²K'
#  'Average thermal transmittance 0.11 W/m²K'
#  'Average thermal transmittance 0.23 W/m²K'
#  'Thatched, with additional insulation' 'Pitched, loft insulation'
#  'Ar oleddf, 100mm o inswleiddio yn y llofft'
#  'Ar oleddf, 150mm o inswleiddio yn y llofft'
#  'Average thermal transmittance 0.67 W/m²K'
#  'Average thermal transmittance 0.27 W/m²K' nan
#  'Average thermal transmittance 0.06 W/m²K'
#  'Pitched, Flat Roof Insulation loft insulation'
#  'Average thermal transmittance 0.28 W/m²K'
#  'Average thermal transmittance 0.01 W/m²K'
#  'Average thermal transmittance 0.03 W/m²K'
#  'Pitched, 11mm loft insulation' 'Average thermal transmittance 0.5 W/m²K'
#  'Average thermal transmittance 0.56 W/m²K' 'Pitched, 1mm loft insulation'
#  'Pitched, insulated' 'Flat, no insulation'
#  'Average thermal transmittance 0.07 W/m²K'
#  'Average thermal transmittance 0.4 W/m²K'
#  'Average thermal transmittance 0.45 W/m²K'
#  'Roof room(s), limited insulation'
#  'Ar oleddf, 250mm o inswleiddio yn y llofft'
#  'Pitched, limited insulation' 'Average thermal transmittance 0.29 W/m²K'
#  'Ar oleddf, 75mm o inswleiddio yn y llofft'
#  'Average thermal transmittance 0.7 W/m²K'
#  'Pitched, 400mm loft insulation' 'Pitched, 350mm loft insulation'
#  'Pitched, 400+mm loft insulation'
#  'Ar oleddf, 50mm o inswleiddio yn y llofft'
#  'Ar oleddf, 12mm o inswleiddio yn y llofft'
#  'Average thermal transmittance 0.35 W/m²K'
#  'Average thermal transmittance 0.38 W/m²K'
#  'Average thermal transmittance 0.48 W/m²K'
#  'Average thermal transmittance 0.33 W/m²K'
#  'Average thermal transmittance 0.34 W/m²K'
#  'Average thermal transmittance 2.54 W/m²K'
#  'Average thermal transmittance 0.3 W/m²K'
#  'Average thermal transmittance 1.6 W/m²K'
#  'Average thermal transmittance 0.32 W/m²K'
#  'Average thermal transmittance 0.78 W/m²K'
#  'Average thermal transmittance 1.12 W/m²K'
#  'Average thermal transmittance -0.19 W/m²K'
#  'Average thermal transmittance 0.58 W/m²K'
#  'Average thermal transmittance 0.49 W/m²K'
#  'Average thermal transmittance 2.3 W/m²K'
#  'Average thermal transmittance 0.46 W/m²K'
#  'Average thermal transmittance 0.39 W/m²K'
#  'Average thermal transmittance 1.0 W/m²K'
#  'Average thermal transmittance 0.8 W/m²K'
#  'Average thermal transmittance 1.03 W/m²K'
#  'Average thermal transmittance 3.88 W/m²K'
#  'Average thermal transmittance 0.37 W/m²K']
#
# Variable: address2
# [nan 'Montano Drive' 'Shirley' ... 'Tobiasfield Court' '7 Ownall Road'
#  '347 Gillott Road']
#
# Variable: hot-water-env-eff
# ['Very Good' 'Poor' 'Good' nan 'Average' 'Very Poor']
#
# Variable: posttown
# ['BIRMINGHAM' 'WOLVERHAMPTON' 'WALSALL' 'SOLIHULL' 'WEDNESBURY'
#  'HALESOWEN' 'COVENTRY' 'BRIERLEY HILL' 'SMETHWICK' 'CRADLEY HEATH'
#  'SUTTON COLDFIELD' 'ROWLEY REGIS' 'BILSTON' 'WEST BROMWICH' 'STOURBRIDGE'
#  'TIPTON' 'DUDLEY' 'WILLENHALL' 'KINGSWINFORD' 'OLDBURY' 'KENILWORTH'
#  'BALSALL COMMON' 'BRIMINGHAM' 'BIRMIGNHAM' 'BRIERELY HILL'
#  'BIRMINGHAM \xa0' 'WEST MIDLANDS' 'BIRMNGHAM' 'CASTLE BROMWICH'
#  'WOOLVERHAMPTON' 'YARDLEY WOOD' 'WOLVERHAMPON' 'BRIERLY HILL' 'ALDRIDGE'
#  'BIRMINGAHM' 'BIRMINAGHAM' 'BRIERLEY  HILL' 'TIPON' 'BIRMINHAM'
#  'BIRMINGAHAM' 'BIRMIGHAM' 'WILENHALL' 'SMETHICK' 'BIRMINGHM' 'HANDSWORTH'
#  'BIMINGHAM' 'WALLSALL' 'BLOXWICH' 'SUTTON COALFIELD' 'SOILHULL'
#  'SOLIHILL' 'SOLIHULLL' 'WOLVERHANPTON' 'WOLVERHAMOTON' 'WOLVERHAMPTONN'
#  'BRMINGHAM' 'WALSAL' 'WEDNSBURY' 'OULTON' 'BLISTON' 'WEST BROWICH'
#  'BRIERLEYHILL' 'BIRMINGAM' 'CORLEY' 'CORLEY MOOR' 'BIRNMINGHAM'
#  'BIRIMINGHAM' 'SMETHIWICK' 'BIRMINHGAM' 'BRERLEY HILL' 'WILLENHALLL'
#  'WOLVEHAMPTON' 'PELSALL' 'DARLASTON' 'Coventry' 'BIMRINGHAM' 'COBVENTRY'
#  'BROWNHILLS' 'WIILENHALL' 'BIRMINGHAM.' 'SHELFIELD' 'Halesowen'
#  'West Bromwich' 'BIRMNINGHAM' 'Birmingham' 'Wolverhampton' 'BOURNVILLE'
#  'RUSHALL' 'OLDSWINFORD' 'NETHERTON' 'COSELEY' 'WOLLESCOTE' 'Sandwell'
#  'QUARRY BANK' 'Wednesbury' 'Oldbury' 'STREETLY' 'Smethwick' 'WORDSLEY'
#  'Tipton' 'Stourbridge' 'WALSALL WOOD' 'PENSNETT' 'CRADLEY' 'AMBLECOTE'
#  'SEDGLEY' 'GREAT BARR' 'LOWER GORNAL' 'BROCKMOOR' 'WOODSETTON' 'Solihull'
#  'UPPER GORNAL' 'CLAYHANGER' 'WOLLASTON' 'BENTLEY' 'PEDMORE' 'LYE'
#  'WALL HEATH' 'HAYLEY GREEN' 'wolverhampton' 'COVENTRY ' 'Cardley Heath'
#  'Cradley Heath' 'Sutton Coldfield' 'Kingswinford' 'Bilston' 'NORTON'
#  'Walsall' 'Rowley Regis' 'Bartley Green' '.' 'Willenhall' 'Brierley Hill'
#  'Dudley' 'Stirchley' 'Halesowen, West Midlands' 'BIrmingham' 'MOXLEY'
#  'Netherton' 'Balsall Common' 'HURST GREEN' 'SANDHILLS' 'Birmimgham'
#  'Minworth' 'WORDESLEY' 'Kenilworth' 'WILLENALL' 'West Midland'
#  'West Midlands' 'RUBERY' 'Aldridge' nan 'WOVERHAMPTON' 'B,ham' 'BRANDON'
#  'ESSINGTON' 'Streetly' 'LOWER PENN' 'LLOYD HILL' 'Birminham' ' COVENTRY'
#  'SUTTON COLFFIELD' 'WILLENHLL' 'BEARWOOD' 'birmingham' ' SMETHWICK'
#  'CONVENTRY' 'WOLVERHAPTON' 'Bloxwich' 'COVENTRY,' 'Birmingham '
#  'Sutton Coldfield ' 'Kingsway' 'SOLiHULL' 'Lower Gornal' 'Brownhills'
#  'LEAMORE' 'Solihull ' 'NEW TOWN' 'BIRMINGHAM ' ' Birmingham' 'SELLY OAK'
#  'WOLVERHAMPTON ' 'Wolverhampton ' 'Coseley' 'Erdington'
#  'SUTTON COLDFIELD ' ' WOLVERHAMPTON' 'WEST MIDLANDS ' ' WALSALL'
#  'Balsall Heath' ' SOLIHULL' 'Sedgley' 'Coventry ' 'Wednesbury '
#  'HALESOWEN ' ' OLDBURY' ' BIRMINGHAM' 'Tipton ' ' HALESOWEN' 'SOLIHULL '
#  'Wednesfield' 'Wol' ' WILLENHALL' 'DUDLEY ' 'BIRMINGHAM, '
#  'KINGSWINFORD ' 'Knowle' 'bilston' 'Bilston ' 'SMETHWICK ' 'S'
#  'West bromwich' 'Shirley ' 'Willienhall ' 'STOURBRIDGE,' 'Brierley Hill '
#  'Wordsley' 'Willenhall ' 'Birmigham' 'Mappleborough Green' 'Walsall '
#  'Cradley Close' 'Cradley Heaht' 'HOCKLEY HEATH' 'Saltley' ' WEDNESBURY'
#  'Shirley' ' SUTTON COLDFIELD' ' CRADLEY HEATH' 'Oldbury ']
#
# Variable: mainheatc-energy-eff
# ['Average' 'Good' 'Very Good' 'Poor' 'Very Poor' nan]
#
# Variable: main-fuel
# ['mains gas' nan 'electricity'
#  'Electricity: electricity, unspecified tariff' 'oil' 'LPG'
#  'smokeless coal' 'biomass'
#  'To be used only when there is no heating/hot-water system'
#  'dual fuel - mineral + wood' 'wood logs' 'house coal' 'LPG (community)'
#  'mains gas (community)' 'mains gas (not community)'
#  'electricity (not community)' 'LPG (not community)' 'oil (not community)'
#  'house coal (not community)' 'electricity (community)' 'anthracite'
#  'biomass (community)' 'oil (community)' 'bottled LPG'
#  'LPG special condition' 'bulk wood pellets' 'B30D (community)'
#  'appliances able to use mineral oil or liquid biofuel'
#  'B30K (not community)' 'waste combustion (community)' 'wood chips'
#  'biogas (community)' 'Gas: mains gas' 'Gas: bulk LPG'
#  'To be used only when there is no heating/hot-water system or data is from a community network'
#  'heat from boilers using biodiesel from any biomass source (community)'
#  'Oil: heating oil' 'from heat network data (community)'
#  'Gas: bottled LPG']
#
# Variable: lighting-env-eff
# ['Very Good' 'Average' 'Very Poor' 'Poor' 'Good' nan]
#
# Variable: windows-energy-eff
# ['Average' 'Good' 'Poor' 'Very Good' 'Very Poor' nan]
#
# Variable: lighting-description
# ['low energy lighting in 90% of fixed outlets'
#  'low energy lighting in 30% of fixed outlets'
#  'low energy lighting in 70% of fixed outlets'
#  'low energy lighting in 33% of fixed outlets'
#  'low energy lighting in 42% of fixed outlets'
#  'low energy lighting in 36% of fixed outlets'
#  'low energy lighting in all fixed outlets' 'no low energy lighting'
#  'low energy lighting in 14% of fixed outlets'
#  'low energy lighting in 17% of fixed outlets'
#  'low energy lighting in 66% of fixed outlets'
#  'low energy lighting in 50% of fixed outlets'
#  'low energy lighting in 10% of fixed outlets'
#  'low energy lighting in 0% of fixed outlets'
#  'low energy lighting in 69% of fixed outlets'
#  'low energy lighting in 21% of fixed outlets'
#  'low energy lighting in 53% of fixed outlets'
#  'low energy lighting in 100% of fixed outlets'
#  'low energy lighting in 25% of fixed outlets'
#  'low energy lighting in 40% of fixed outlets'
#  'low energy lighting in 85% of fixed outlets'
#  'low energy lighting in 20% of fixed outlets'
#  'low energy lighting in 15% of fixed outlets' 'sap05:lighting'
#  'low energy lighting in 95% of fixed outlets'
#  'low energy lighting in 60% of fixed outlets'
#  'low energy lighting in 80% of fixed outlets'
#  'low energy lighting in 92% of fixed outlets'
#  'low energy lighting in 75% of fixed outlets'
#  'low energy lighting in 77% of fixed outlets'
#  'low energy lighting in 63% of fixed outlets'
#  'low energy lighting in 29% of fixed outlets'
#  'low energy lighting in 86% of fixed outlets'
#  'low energy lighting in 11% of fixed outlets'
#  'low energy lighting in 22% of fixed outlets'
#  'low energy lighting in 71% of fixed outlets'
#  'low energy lighting in 38% of fixed outlets'
#  'low energy lighting in 5% of fixed outlets'
#  'low energy lighting in 6% of fixed outlets'
#  'low energy lighting in 9% of fixed outlets'
#  'low energy lighting in 45% of fixed outlets'
#  'low energy lighting in 27% of fixed outlets'
#  'low energy lighting in 58% of fixed outlets'
#  'low energy lighting in 44% of fixed outlets'
#  'low energy lighting in 28% of fixed outlets'
#  'low energy lighting in 12% of fixed outlets'
#  'low energy lighting in 24% of fixed outlets'
#  'low energy lighting in 13% of fixed outlets'
#  'low energy lighting in 31% of fixed outlets'
#  'low energy lighting in 35% of fixed outlets'
#  'low energy lighting in 57% of fixed outlets'
#  'low energy lighting in 62% of fixed outlets'
#  'low energy lighting in 67% of fixed outlets'
#  'low energy lighting in 55% of fixed outlets'
#  'low energy lighting in 8% of fixed outlets'
#  'low energy lighting in 4% of fixed outlets'
#  'low energy lighting in 72% of fixed outlets'
#  'low energy lighting in 16% of fixed outlets'
#  'low energy lighting in 59% of fixed outlets'
#  'low energy lighting in 32% of fixed outlets'
#  'low energy lighting in 52% of fixed outlets'
#  'low energy lighting in 18% of fixed outlets'
#  'low energy lighting in 82% of fixed outlets'
#  'low energy lighting in 78% of fixed outlets'
#  'low energy lighting in 7% of fixed outlets'
#  'low energy lighting in 37% of fixed outlets'
#  'low energy lighting in 23% of fixed outlets'
#  'low energy lighting in 39% of fixed outlets'
#  'low energy lighting in 93% of fixed outlets'
#  'low energy lighting in 64% of fixed outlets'
#  'low energy lighting in 91% of fixed outlets'
#  'low energy lighting in 79% of fixed outlets'
#  'low energy lighting in 43% of fixed outlets'
#  'low energy lighting in 83% of fixed outlets'
#  'low energy lighting in 65% of fixed outlets'
#  'low energy lighting in 56% of fixed outlets'
#  'low energy lighting in 88% of fixed outlets'
#  'low energy lighting in 54% of fixed outlets'
#  'low energy lighting in 34% of fixed outlets'
#  'low energy lighting in 73% of fixed outlets'
#  'low energy lighting in 89% of fixed outlets'
#  'low energy lighting in 46% of fixed outlets'
#  'low energy lighting in 26% of fixed outlets'
#  'low energy lighting in 47% of fixed outlets'
#  'low energy lighting in 19% of fixed outlets'
#  'low energy lighting in 76% of fixed outlets'
#  'low energy lighting in 41% of fixed outlets'
#  'low energy lighting in 87% of fixed outlets'
#  'low energy lighting in 2% of fixed outlets'
#  'low energy lighting in 3% of fixed outlets'
#  'low energy lighting in 48% of fixed outlets'
#  'low energy lighting in 1% of fixed outlets'
#  'low energy lighting in 61% of fixed outlets'
#  'low energy lighting in 81% of fixed outlets'
#  'low energy lighting in 49% of fixed outlets'
#  'low energy lighting in 96% of fixed outlets'
#  'low energy lighting in 68% of fixed outlets'
#  'low energy lighting in 33% fixed outlets'
#  'low energy lighting in 45% fixed outlets'
#  'low energy lighting in 31% fixed outlets'
#  'low energy lighting in 26% fixed outlets'
#  'low energy lighting in 60% fixed outlets'
#  'low energy lighting in 50% fixed outlets'
#  'low energy lighting in 44% fixed outlets'
#  'low energy lighting in 70% fixed outlets'
#  'low energy lighting in 36% fixed outlets'
#  'low energy lighting in 38% fixed outlets'
#  'low energy lighting in 84% of fixed outlets'
#  'low energy lighting in 67% fixed outlets'
#  'low energy lighting in 25% fixed outlets'
#  'low energy lighting in 63% fixed outlets'
#  'low energy lighting in 78% fixed outlets'
#  'low energy lighting in 42% fixed outlets'
#  'low energy lighting in 80% fixed outlets'
#  'low energy lighting in 71% fixed outlets'
#  'low energy lighting in 21% fixed outlets'
#  'low energy lighting in 29% fixed outlets'
#  'low energy lighting in 37% fixed outlets'
#  'low energy lighting in 30% fixed outlets'
#  'low energy lighting in 51% of fixed outlets'
#  'low energy lighting in 74% of fixed outlets'
#  'low energy lighting in 57% fixed outlets'
#  'low energy lighting in 20% fixed outlets'
#  'low energy lighting in 27% fixed outlets'
#  'low energy lighting in 98% of fixed outlets'
#  'low energy lighting in 43% fixed outlets'
#  'low energy lighting in 24% fixed outlets'
#  'low energy lighting in 40% fixed outlets'
#  'low energy lighting in 22% fixed outlets'
#  "goleuadau ynni-isel mewn 35% o'r mannau gosod"
#  'low energy lighting in 94% of fixed outlets' 'dim goleuadau ynni-isel'
#  'low energy lighting in 35% fixed outlets'
#  'low energy lighting in 19% fixed outlets'
#  'low energy lighting in 28% fixed outlets'
#  'low energy lighting in 17% fixed outlets'
#  'low energy lighting in 11% fixed outlets'
#  'low energy lighting in 23% fixed outlets'
#  'low energy lighting in 93% fixed outlets'
#  'low energy lighting in 56% fixed outlets' nan
#  'low energy lighting in 97% of fixed outlets'
#  'low energy lighting in 99% of fixed outlets'
#  'low energy lighting in 52% fixed outlets'
#  'low energy lighting in 33.33333% of fixed outlets'
#  'low energy lighting in 81.8% of fixed outlets'
#  'low energy lighting in 58.33333% of fixed outlets'
#  'low energy lighting in 35.7% of fixed outlets'
#  'low energy lighting in 38.5% of fixed outlets'
#  'low energy lighting in 33.3% of fixed outlets'
#  'low energy lighting in 41.7% of fixed outlets'
#  'low energy lighting in 45.5% of fixed outlets'
#  'low energy lighting in 42.1% of fixed outlets'
#  'low energy lighting in 43.8% of fixed outlets'
#  'low energy lighting in 9.1% of fixed outlets'
#  'low energy lighting in 36.4% of fixed outlets'
#  'low energy lighting in 42.9% of fixed outlets'
#  'low energy lighting in 35.3% of fixed outlets'
#  'low energy lighting in 37.5% of fixed outlets'
#  'low energy lighting in 86.4% of fixed outlets'
#  'low energy lighting in 77.8% of fixed outlets'
#  'low energy lighting in 53.3% of fixed outlets'
#  'goleuadau ynni-isel mewn 33% o?r mannau gosod'
#  'goleuadau ynni-isel mewn 29% o?r mannau gosod'
#  'low energy lighting in 90.9% of fixed outlets'
#  'goleuadau ynni-isel mewn 50% o?r mannau gosod'
#  'goleuadau ynni-isel mewn 86% o’r mannau gosod'
#  'goleuadau ynni-isel mewn 50% o’r mannau gosod'
#  'goleuadau ynni-isel mewn 57% o’r mannau gosod'
#  'goleuadau ynni-isel mewn 63% o’r mannau gosod'
#  'goleuadau ynni-isel mewn 17% o’r mannau gosod'
#  'goleuadau ynni-isel mewn 22% o’r mannau gosod'
#  'goleuadau ynni-isel ym mhob un o’r mannau gosod']
#
# Variable: roof-env-eff
# ['Poor' 'Very Good' 'Average' nan 'Good' 'Very Poor']
#
# Variable: walls-energy-eff
# ['Good' 'Very Good' 'Very Poor' 'Poor' 'Average' nan]
#
# Variable: mainheat-env-eff
# ['Very Good' 'Very Poor' 'Good' 'Average' nan 'Poor']
#
# Variable: main-heating-controls
# [2106.   nan 2110. 2402. 2104. 2102. 2502. 2107. 2109. 2305. 2401. 2101.
#  2504. 2303. 2602. 2605. 2705. 2301. 2103. 2501. 2601. 2703. 2699. 2105.
#  2603. 2701. 2706. 2704. 2304. 2302. 2503. 2306. 2505. 2403. 2506. 2201.
#  2604. 2108. 2204. 2307. 2111. 2309. 2404. 2702. 2206. 2100.]
#
# Variable: lodgement-datetime
# ['2008-11-24 17:44:11' '2009-01-12 11:04:46' '2009-01-12 11:03:17' ...
#  '2022-03-31 20:46:25' '2022-03-31 09:20:53' '2022-03-31 11:15:30']
#
# Variable: current-energy-rating
# ['C' 'B' 'E' 'D' 'G' 'F' nan 'A']
#
# Variable: secondheat-description
# ['None' 'Room heaters, electric' 'Room heaters, mains gas'
#  'Room heaters, smokeless fuel' 'Room heaters, coal'
#  'SAP05:Secondary-Heating' 'Room heaters, wood logs'
#  'Portable electric heaters' 'Room heaters, bottled gas'
#  'Room heaters, dual fuel (mineral and wood)' 'Room heaters, oil'
#  'Room heaters, LPG' 'Room heaters, anthracite'
#  'Electric Underfloor Heating (Standard tariff), electric'
#  'Gwresogyddion ystafell, nwy prif gyflenwad'
#  'Gwresogyddion trydan cludadwy' 'Room heaters, bulk LPG'
#  'Room heaters, wood chips' 'Room heaters' 'Room heaters, smokeless Fuel'
#  'Room heaters, wood pellets' 'Room heaters, bottled LPG'
#  'LPG room heaters, gas' 'Dim' 'Room heaters, bioethanol'
#  'Gwresogyddion ystafell, trydan']
#
# Variable: walls-env-eff
# ['Good' 'Very Good' 'Very Poor' 'Poor' 'Average' nan]
#
# Variable: transaction-type
# ['marketed sale' 'new dwelling' 'rental (social)' 'rental (private)'
#  'non marketed sale' nan 'none of the above' 'rental' 'FiT application'
#  'assessment for green deal' 'following green deal' 'ECO assessment'
#  'RHI application' 'Stock condition survey' 'not sale or rental']
#
# Variable: mainheat-description
# ['Boiler and radiators, mains gas'
#  'Boiler and underfloor heating, mains gas' 'Electric storage heaters'
#  'Warm air, mains gas' 'Room heaters, electric' 'Community scheme'
#  'SAP05:Main-Heating' 'Boiler and radiators, electric'
#  'Room heaters, mains gas' 'Electric underfloor heating'
#  'Boiler and radiators, oil' 'No system present: electric heaters assumed'
#  'Portable electric heating assumed for most rooms' 'Warm air, electric'
#  'Ground source heat pump, warm air, electric'
#  'Water source heat pump, warm air, electric' 'Community scheme with CHP'
#  'Boiler and radiators, LPG'
#  'Boiler and radiators, dual fuel (mineral and wood)'
#  'Community, community' 'Warm air, Electricaire' 'Room heaters, oil'
#  'Room heaters, coal' 'Room heaters, dual fuel (mineral and wood)'
#  'Portable electric heaters assumed for most rooms'
#  'Room heaters, smokeless fuel' 'Boiler and underfloor heating, electric'
#  'Ground source heat pump, radiators, electric'
#  'Electric Underfloor Heating (Standard tariff), electric'
#  'Boiler and radiators, coal' 'Portable electric heaters'
#  'Water source heat pump, radiators, electric'
#  'Boiler and radiators, anthracite' 'Community scheme, mains gas'
#  'Boiler and underfloor heating, LPG'
#  'Boiler and radiators, smokeless fuel'
#  'Air source heat pump, radiators, electric' 'Room heaters, wood logs'
#  'Bwyler a rheiddiaduron, nwy prif gyflenwad'
#  'Awyr gynnes, nwy prif gyflenwad'
#  'Community scheme with CHP and mains gas'
#  'Air source heat pump, ratiators, electric'
#  'Air source heat pump, underfloor, electric' 'Electric ceiling heating'
#  'Boiler and radiators, ' 'Warm air, oil'
#  'Ground source heat pump, underfloor, electric'
#  'Boiler and radiators, wood logs'
#  'Community scheme, radiators, mains gas'
#  'Boiler and radiators, wood chips' 'Boiler, mains gas'
#  'Boiler and underfloor heating, oil' 'Air source heat pump, '
#  'Room heaters, ' 'Room heaters, electricity'
#  'Air source heat pump, radiators, electricity'
#  'Air source heat pump, , radiators, electric'
#  'No system present: electric heaters assumed, mains gas'
#  'No system present: electric heaters assumed, gas'
#  'Community scheme with CHP, mains gas'
#  'No system present: electric heaters assumed, radiators' 'Warm air, LPG'
#  'Portable electric heating assumed for most rooms, electric'
#  'Boiler, anthracite' 'Air source heat pump, fan coil units, electric'
#  'Room heaters, LPG' 'Electric ceiling heating, electric' 'Room heaters'
#  'Boiler and radiators' 'Air source heat pump, warm air, electric'
#  'Boiler and radiators, bottled LPG' 'Micro-cogeneration, mains gas' nan
#  'Boiler and radiators, wood pellets'
#  'Air source heat pump, warm air, mains gas'
#  'Boiler & underfloor, mains gas' 'Boiler and radiators, B30K'
#  'Room heaters, bottled LPG' 'Room heaters, wood chips'
#  'Electric ceiling heating, underfloor, electric'
#  'Boiler and underfloor heating, wood logs'
#  'Ground source heat pump, underfloor, mains gas'
#  'Ground source heat pump, Underfloor heating and radiators, pipes in screed above insulation, electric'
#  'Electric storage heaters, radiators' 'Electric heat pumps, electric'
#  'Room heaters, anthracite'
#  'Air source heat pump, Underfloor heating, pipes in screed above insulation, electric'
#  'Boiler & underfloor, wood pellets'
#  'Electric storage heaters, underfloor' 'Boiler & underfloor, oil'
#  'Water source heat pump, underfloor, mains gas'
#  'Room heaters, radiators, electric'
#  'Air source heat pump, Systems with radiators, electric'
#  'Air source heat pump, Underfloor heating and radiators, pipes in screed above insulation, electric'
#  'Ground source heat pump, radiators, mains gas'
#  'Air source heat pump, Underfloor heating, pipes in insulated timber floor, electric'
#  'Boiler & underfloor, electric' 'Air source heat pump , electric'
#  'Water source heat pump, underfloor, electric'
#  'Room heaters, dual fuel (mineral and wood), Electric storage heaters'
#  'Room heaters, electric, Electric storage heaters'
#  'Electric storage heaters, Electric storage heaters'
#  'Boiler and radiators, mains gas, Boiler and radiators, mains gas'
#  'Boiler and radiators, mains gas, Electric storage heaters'
#  'Boiler and radiators, mains gas, Boiler and underfloor heating, mains gas'
#  'Room heaters, mains gas, Room heaters, electric'
#  'Boiler and radiators, mains gas, Electric underfloor heating'
#  'Electric storage heaters, Room heaters, mains gas'
#  'Warm air, mains gas, Boiler and radiators, mains gas'
#  'Warm air, mains gas, Electric storage heaters'
#  'Electric storage heaters, Room heaters, electric'
#  'Boiler and radiators, mains gas, Room heaters, wood logs'
#  'Boiler and radiators, mains gas, Boiler and radiators, electric'
#  'Boiler and underfloor heating, mains gas, Room heaters, electric'
#  'Boiler and underfloor heating, mains gas, Boiler and radiators, mains gas'
#  'Boiler and radiators, mains gas, Room heaters, electric'
#  'Boiler and underfloor heating, mains gas, Air source heat pump, warm air, electric'
#  'Room heaters, electric, Room heaters, electric'
#  'Boiler and radiators, mains gas, Room heaters, mains gas'
#  'Boiler and radiators, mains gas, Air source heat pump, underfloor, electric'
#  'Boiler & underfloor, LPG'
#  'Room heaters, mains gas, Room heaters, mains gas'
#  'Boiler and underfloor heating, mains gas, Boiler and underfloor heating, mains gas'
#  'Boiler and radiators, mains gas, Room heaters, dual fuel (mineral and wood)'
#  'Room heaters, electric, Room heaters, mains gas'
#  'Room heaters, mains gas, Electric storage heaters'
#  'Room heaters, coal, Room heaters, electric'
#  'Room heaters, electric, Room heaters, coal'
#  'Room heaters, electric, Room heaters, dual fuel (mineral and wood)'
#  'Boiler & underfloor, mains gas, Boiler And underfloor heating, mains gas'
#  'Air source heat pump, radiators, electric, Air source heat pump, underfloor, electric'
#  'Room heaters, mains gas, Room heaters, coal'
#  'Room heaters, mains gas, Room heaters, anthracite'
#  'Room heaters, mains gas, Room heaters, smokeless fuel'
#  'Water source heat pump, radiators, mains gas'
#  'Boiler and underfloor heating, oil, Air source heat pump, warm air, electric'
#  'Electric storage heaters, Electric underfloor heating'
#  'Portable electric heaters assumed for most rooms, Room heaters, electric'
#  'Room heaters, electric, Room heaters, smokeless fuel'
#  'Electric underfloor heating, Room heaters, electric'
#  'Room heaters, mains gas, Room heaters, dual fuel (mineral and wood)'
#  'Electric storage heaters, Boiler and radiators, mains gas'
#  'Electric storage heaters, Room heaters, smokeless fuel']
#
# Variable: mainheatc-env-eff
# ['Average' 'Good' 'Very Good' 'Poor' 'Very Poor' nan]
#
# Variable: tenure
# ['owner-occupied' nan 'rental (social)' 'rental (private)']
#
# Variable: floor-level
# [nan 'Ground' '1st' 'top floor' 'mid floor' '' '1' '1Groundth'
#  '21st or above' '2Groundth' '-1' 'Ground4' 'Ground1' 'Ground2' 'Ground9'
#  'Ground3' '3' 'Ground7' '12' 'Ground5' 'Ground6' '2Ground+' '11'
#  '1Ground' '2' 'Ground8' '16' '19' '15' '18' '14' '2Ground' '17' '13']
#
# Variable: hot-water-energy-eff
# ['Very Good' 'Poor' 'Average' 'Very Poor' nan 'Good']
#
# Variable: walls-description
# ['Cavity wall, filled cavity' 'Average thermal transmittance 0.30 W/m²K'
#  'Average thermal transmittance 0.27 W/m²K' 'Solid brick, no insulation'
#  'Average thermal transmittance 0.22 W/m²K'
#  'Average thermal transmittance 0.24 W/m²K'
#  'Average thermal transmittance 0.34 W/m²K'
#  'Average thermal transmittance 0.38 W/m²K'
#  'Average thermal transmittance 0.39 W/m²K'
#  'Average thermal transmittance 0.26 W/m²K'
#  'Average thermal transmittance 0.29 W/m²K' 'Cavity wall, insulated'
#  'Solid brick, insulated' 'Cavity wall, no insulation'
#  'System built, no insulation' 'Average thermal transmittance 0.20 W/m²K'
#  'Average thermal transmittance 0.28 W/m²K'
#  'Average thermal transmittance 0.31 W/m²K'
#  'Average thermal transmittance 0.36 W/m²K'
#  'Average thermal transmittance 0.37 W/m²K'
#  'Average thermal transmittance 0.33 W/m²K'
#  'Average thermal transmittance 0.32 W/m²K'
#  'Cavity wall, partial insulation' 'System built, insulated' 'SAP05:Walls'
#  'Timber frame, partial insulation'
#  'Average thermal transmittance 0.25 W/m²K' 'Timber frame, insulated'
#  'Sandstone, no insulation' 'System built, partial insulation'
#  'Timber frame, no insulation' 'Average thermal transmittance 0.42 W/m²K'
#  'Average thermal transmittance 0.48 W/m²K'
#  'Solid brick, partial insulation' 'Timber frame, filled cavity'
#  'Average thermal transmittance 0.35 W/m²K' 'Granite or whin, insulated'
#  'Average thermal transmittance 0.50 W/m²K'
#  'Average thermal transmittance 0.44 W/m²K'
#  'Average thermal transmittance 0.41 W/m²K'
#  'Average thermal transmittance 0.40 W/m²K'
#  'Average thermal transmittance 0.46 W/m²K'
#  'Average thermal transmittance 0.47 W/m²K'
#  'Average thermal transmittance 0.23 W/m²K'
#  'Average thermal transmittance 0.45 W/m²K'
#  'Average thermal transmittance 0.43 W/m²K'
#  'Average thermal transmittance 0.97 W/m²K'
#  'Average thermal transmittance 0.75 W/m²K'
#  'Average thermal transmittance 0.88 W/m²K'
#  'Average thermal transmittance 0.49 W/m²K'
#  'Average thermal transmittance 0.52 W/m²K'
#  'Average thermal transmittance 1.12 W/m²K' 'Sandstone, insulated'
#  'Average thermal transmittance 0.21 W/m²K' 'Cob, as built'
#  'Average thermal transmittance 0.94 W/m²K'
#  'Average thermal transmittance 1.83 W/m²K'
#  'Average thermal transmittance 0.65 W/m²K'
#  'Wediu hadeiladu yn l system, fel yu hadeiladwyd, dim inswleiddio (rhagdybiaeth)'
#  'Waliau ceudod, fel yu hadeiladwyd, inswleiddio rhannol (rhagdybiaeth)'
#  'Average thermal transmittance 0.17 W/m²K'
#  'Average thermal transmittance 0.16 W/m²K'
#  'Average thermal transmittance 1.57 W/m²K'
#  'Average thermal transmittance 0.19 W/m²K'
#  'Average thermal transmittance 0.18 W/m²K'
#  'Average thermal transmittance 0.51 W/m²K'
#  'Average thermal transmittance 0.53 W/m²K' 'Solid brick, filled cavity'
#  'Average thermal transmittance 1.07 W/m²K'
#  'Average thermal transmittance 1.97 W/m²K'
#  'Average thermal transmittance 1.38 W/m²K'
#  'Average thermal transmittance 1.15 W/m²K'
#  'Sandstone, partial insulation' 'Granite or whin, no insulation'
#  'System built, filled cavity' 'Average thermal transmittance 0.14 W/m²K'
#  'Average thermal transmittance 1.47 W/m²K'
#  'Average thermal transmittance 0.90 W/m²K'
#  'Average thermal transmittance 0.98 W/m²K'
#  'Average thermal transmittance 0.74 W/m²K'
#  'Average thermal transmittance 0.96 W/m²K'
#  'Average thermal transmittance 0.93 W/m²K'
#  'Average thermal transmittance 0.99 W/m²K'
#  'Average thermal transmittance 1.08 W/m²K'
#  'Average thermal transmittance 1.59 W/m²K'
#  'Average thermal transmittance 1.54 W/m²K'
#  'Average thermal transmittance 1.04 W/m²K'
#  'Average thermal transmittance 0.89 W/m²K'
#  'Average thermal transmittance 1.77 W/m²K'
#  'Average thermal transmittance 1.56 W/m²K'
#  'Average thermal transmittance 1.45 W/m²K'
#  'Average thermal transmittance 0.79 W/m²K'
#  'Average thermal transmittance 1.13 W/m²K'
#  'Average thermal transmittance 1.46 W/m²K'
#  'Average thermal transmittance 1.03 W/m²K'
#  'Average thermal transmittance 1.41 W/m²K'
#  'Average thermal transmittance 0.87 W/m²K'
#  'Average thermal transmittance 1.09 W/m²K' 'Cavity wall'
#  'Average thermal transmittance 1.94 W/m²K'
#  'Average thermal transmittance 1.93 W/m²K'
#  'Average thermal transmittance 0.11 W/m²K'
#  'Average thermal transmittance 0.08 W/m²K' nan
#  'Average thermal transmittance 2.19 W/m²K'
#  'Average thermal transmittance 0.10 W/m²K'
#  'Average thermal transmittance 0.09 W/m²K'
#  'Average thermal transmittance 0.84 W/m²K'
#  'Average thermal transmittance 0.13 W/m²K'
#  'Average thermal transmittance 0.91 W/m²K'
#  'Average thermal transmittance 0.82 W/m²K'
#  'Average thermal transmittance 0.83 W/m²K'
#  'Average thermal transmittance 1.01 W/m²K'
#  'Cavity wall, filled cavity and internal insulation'
#  'Cavity wall, filled cavity and external insulation'
#  'Granite or whinstone, insulated'
#  'Average thermal transmittance 0.57 W/m²K'
#  'Average thermal transmittance 2.10 W/m²K'
#  'Average thermal transmittance 1.48 W/m²K'
#  'Average thermal transmittance 1.29 W/m²K'
#  'Average thermal transmittance 1.55 W/m²K'
#  'Average thermal transmittance 1.36 W/m²K'
#  'Average thermal transmittance 1.66 W/m²K'
#  'Average thermal transmittance 1.28 W/m²K'
#  'Average thermal transmittance 1.33 W/m²K'
#  'Average thermal transmittance 1.31 W/m²K'
#  'Average thermal transmittance 0.15 W/m²K'
#  'Granite or whinstone, no insulation'
#  'Average thermal transmittance 0.54 W/m²K'
#  'Average thermal transmittance 0.12 W/m²K'
#  'Waliau ceudod, fel yu hadeiladwyd, dim inswleiddio (rhagdybiaeth)'
#  'Waliau ceudod, ceudod wedii lenwi'
#  'Average thermal transmittance 1.58 W/m²K'
#  'Average thermal transmittance 1.67 W/m²K'
#  'Average thermal transmittance 1.34 W/m²K'
#  'Average thermal transmittance 0 W/m²K'
#  'Average thermal transmittance 2.20 W/m²K'
#  'Average thermal transmittance 1.72 W/m²K'
#  'Average thermal transmittance 3.40 W/m²K'
#  'Average thermal transmittance 1.98 W/m²K'
#  'Average thermal transmittance 1.73 W/m²K'
#  'Average thermal transmittance 1.92 W/m²K'
#  'Sandstone or limestone, no insulation'
#  'Waliau ceudod, fel y’u hadeiladwyd, dim inswleiddio (rhagdybiaeth)'
#  'Park home wall, as built'
#  'Briciau solet, fel y’u hadeiladwyd, dim inswleiddio (rhagdybiaeth)'
#  'Average thermal transmittance 1.90 W/m²K'
#  'Average thermal transmittance 0.60 W/m²K'
#  'Waliau ceudod, fel y’u hadeiladwyd, inswleiddio rhannol (rhagdybiaeth)'
#  'Average thermal transmittance 0.58 W/m²K'
#  'Average thermal transmittance 0.63 W/m²K'
#  'Average thermal transmittance 0.07 W/m²K'
#  'Average thermal transmittance 1.17 W/m²K'
#  'Average thermal transmittance 2.80 W/m²K'
#  'Average thermal transmittance 0.69 W/m²K'
#  'Average thermal transmittance 1.35 W/m²K'
#  'Average thermal transmittance 1.88 W/m²K'
#  'Average thermal transmittance 0.61 W/m²K'
#  'Average thermal transmittance 2.00 W/m²K'
#  'Average thermal transmittance 0.64 W/m²K'
#  'Average thermal transmittance 0.59 W/m²K'
#  'Average thermal transmittance 2.56 W/m²K'
#  'Average thermal transmittance 2.55 W/m²K'
#  'Average thermal transmittance 0.70 W/m²K'
#  'Average thermal transmittance 1.49 W/m²K'
#  'Average thermal transmittance 2.01 W/m²K'
#  'Average thermal transmittance 1.78 W/m²K'
#  'Average thermal transmittance 0.66 W/m²K'
#  'Average thermal transmittance 2.40 W/m²K'
#  'Average thermal transmittance 0.67 W/m²K'
#  'Average thermal transmittance 2.42 W/m²K'
#  'Average thermal transmittance 2.30 W/m²K'
#  'Average thermal transmittance 1.79 W/m²K'
#  'Average thermal transmittance 2.14 W/m²K'
#  'Average thermal transmittance 2.04 W/m²K'
#  'Average thermal transmittance 2.33 W/m²K'
#  'Average thermal transmittance 2.16 W/m²K'
#  'Average thermal transmittance 2.52 W/m²K'
#  'Average thermal transmittance 2.60 W/m²K'
#  'Average thermal transmittance 0.76 W/m²K'
#  'Average thermal transmittance 2.46 W/m²K'
#  'Average thermal transmittance 2.43 W/m²K'
#  'Average thermal transmittance 0.62 W/m²K'
#  'Average thermal transmittance 1.71 W/m²K'
#  'Average thermal transmittance 2.21 W/m²K'
#  'Average thermal transmittance 1.25 W/m²K'
#  'Average thermal transmittance 0.92 W/m²K'
#  'Average thermal transmittance 0.56 W/m²K'
#  'Average thermal transmittance 0.77 W/m²K'
#  'Average thermal transmittance 0.71 W/m²K'
#  'Average thermal transmittance 1.32 W/m²K'
#  'Average thermal transmittance 0.72 W/m²K'
#  'Average thermal transmittance 0.68 W/m²K'
#  'Average thermal transmittance 1.81 W/m²K'
#  'Average thermal transmittance 0.2 W/m²K'
#  'Average thermal transmittance 1.43 W/m²K'
#  'Average thermal transmittance 1.63 W/m²K'
#  'Average thermal transmittance 0.55 W/m²K'
#  'Average thermal transmittance 2.17 W/m²K'
#  'Average thermal transmittance 0.81 W/m²K'
#  'Average thermal transmittance 2.07 W/m²K'
#  'Average thermal transmittance 0.00 W/m²K'
#  'Average thermal transmittance 1.50 W/m²K'
#  'Average thermal transmittance 1.05 W/m²K'
#  'Average thermal transmittance 1.87 W/m²K'
#  'Average thermal transmittance 1.70 W/m²K'
#  'Average thermal transmittance 0.3 W/m²K'
#  'Average thermal transmittance 1.24 W/m²K'
#  'Average thermal transmittance 1.11 W/m²K'
#  'Average thermal transmittance 1.91 W/m²K'
#  'Average thermal transmittance 1.99 W/m²K'
#  'Average thermal transmittance 1.85 W/m²K'
#  'Average thermal transmittance 1.84 W/m²K'
#  'Sandstone or limestone, insulated'
#  'Average thermal transmittance 1.18 W/m²K' 'Park home wall, insulated'
#  'Average thermal transmittance 0.73 W/m²K'
#  'Average thermal transmittance 0.85 W/m²K'
#  'Average thermal transmittance 1.26 W/m²K'
#  'Average thermal transmittance 1.20 W/m²K'
#  'Average thermal transmittance 1.37 W/m²K'
#  'Average thermal transmittance 1.42 W/m²K'
#  'Average thermal transmittance 1.44 W/m²K'
#  'Average thermal transmittance 0.78 W/m²K'
#  'Average thermal transmittance 0.80 W/m²K'
#  'Average thermal transmittance 0.95 W/m²K'
#  'Average thermal transmittance 1.52 W/m²K'
#  'Average thermal transmittance 1.40 W/m²K'
#  'Average thermal transmittance 2.09 W/m²K'
#  'Average thermal transmittance 2.05 W/m²K'
#  'Average thermal transmittance 1.80 W/m²K'
#  'Average thermal transmittance 1.39 W/m²K'
#  'Average thermal transmittance 1.00 W/m²K'
#  'Average thermal transmittance 1.64 W/m²K'
#  'Average thermal transmittance 0.86 W/m²K'
#  'Average thermal transmittance 1.30 W/m²K'
#  'Average thermal transmittance 0.01 W/m²K'
#  'Average thermal transmittance 1.10 W/m²K'
#  'Average thermal transmittance 1.76 W/m²K'
#  'Average thermal transmittance 2.32 W/m²K'
#  'Average thermal transmittance 2.36 W/m²K'
#  'Average thermal transmittance 2.29 W/m²K'
#  'Average thermal transmittance 2.27 W/m²K'
#  'Average thermal transmittance 1.02 W/m²K'
#  'Average thermal transmittance 1.53 W/m²K'
#  'Average thermal transmittance 1.21 W/m²K']
#
# Variable: hotwater-description
# ['From main system' 'Electric immersion, off-peak'
#  'From main system, no cylinderstat' 'Electric immersion, standard tariff'
#  'Electric instantaneous at point of use' 'SAP:Hot-Water'
#  'Oil boiler/circulator' 'No system present: electric immersion assumed'
#  'Gas multipoint' 'Electric immersion, off-peak, no cylinderstat'
#  'From secondary system' 'Gas instantaneous at point of use'
#  'From secondary system, no cylinderstat'
#  'Electric immersion, standard tariff, no cylinderstat'
#  'Electric multipoint' "O'r brif system" 'Twymwr tanddwr, tarriff safonol'
#  'Community scheme' 'Electric immersion, dual tariff'
#  'From main system, standard tariff' 'From main system '
#  'From main system, no cylinderstat, plus solar'
#  'From main system, plus solar'
#  'Single-point gas water heater, standard tariff'
#  'Electric immersion, off-peak ' 'Electric immersion, standard tariff '
#  'Electric immersion, standard tariff, plus solar'
#  'Single-point gas water heater, off-peak' 'Gas boiler/circulator'
#  'Gas boiler/circulator, no cylinderstat' 'Gas range cooker'
#  'Gas range cooker, no cylinderstat' 'Community scheme, no cylinderstat'
#  'No system present: electric immersion assumed, plus solar'
#  'Electric immersion, off-peak, plus solar'
#  'Solid fuel range cooker, no cylinderstat' 'Gas multipoint, plus solar'
#  'Community scheme with CHP' 'From main system, flue gas heat recovery'
#  'Oil range cooker' 'Solid fuel boiler/circulator, no cylinderstat'
#  'From secondary system, plus solar' 'Gas range cooker, plus solar'
#  'O?r brif system' 'Community scheme, plus solar'
#  'No system present: electric immersion assumed, flue gas heat recovery'
#  'Electric instantaneous at point of use, plus solar'
#  'Solid fuel boiler/circulator' 'Gas boiler/circulator, plus solar'
#  'From main system, flue gas heat recovery, plus solar'
#  'Gas instantaneous at point of use, plus solar'
#  'O’r brif system, adfer gwres nwyon ffliw'
#  'From main system, waste water heat recovery'
#  'Oil range cooker, no cylinderstat'
#  'O’r brif system, dim thermostat ar y silindr' 'O’r brif system' nan
#  'Electric heat pump'
#  'From main system, flue gas heat recovery, waste water heat recovery'
#  'Oil boiler/circulator, no cylinderstat'
#  'Electric immersion, standard tariff, waste water heat recovery'
#  'Electric heat pump for water heating only' ', no cylinderstat'
#  'Electric heat pump for water heating only, plus solar'
#  'Electric instantaneous at point of use, waste water heat recovery'
#  'Electric immersion, off-peak, waste water heat recovery'
#  'Community scheme, no cylinderstat, plus solar'
#  'Electric heat pump for water heating only, no cylinderstat' 'Heat pump'
#  'Gas boiler/circulator, no cylinderstat, plus solar'
#  'From secondary system, flue gas heat recovery']
#
# Variable: ladcd
# ['E08000025' 'E08000031' 'E08000030' 'E08000029' 'E08000027' 'E08000026'
#  'E08000028']
#
# Variable: ladnm
# ['Birmingham' 'Wolverhampton' 'Walsall' 'Solihull' 'Dudley' 'Coventry'
#  'Sandwell']
